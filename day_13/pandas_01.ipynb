# %% [markdown]
# # how to import dataset in python using pandas library
# written by : Muhammad Maaz\
# date : 8/8/024\
# maaz50236@gmail.com

# %%
# Step # 01 importing library
import pandas as pd
import openpyxl

# %%
# step:02 
# reading/importing dataset

df = pd.read_excel("pandas_01_day6.xlsx")
# write the path if you want to import data from day:01 to day:06   (assignment)
#print(df)  #or simply df

# %%
df
# there are three portions of data i.e sr,darr,dum
# Out:
#     height  weight favourite_Dish
# 0      5.8     101  Chicken Pulao
# 1      6.2      92        Biryani
# 2      5.9      62  Karahi Ghosht
# 3      5.9      95  Chicken Pulao
# 4      5.9      55  Chicken Pulao
# ..     ...     ...            ...
# 82     5.4      55          Pasta
# 83     5.9      75  Karahi Ghosht
# 84     5.4      61        Biryani
# 85     6.2      68  Chicken Pulao
# 86     5.1      96        Biryani
#
# [87 rows x 3 columns]

# %%
df.tail(8)
# Out:
#     height  weight favourite_Dish
# 79     5.3      62        Biryani
# 80     5.4      55          Pasta
# 81     5.5      52  Karahi Ghosht
# 82     5.4      55          Pasta
# 83     5.9      75  Karahi Ghosht
# 84     5.4      61        Biryani
# 85     6.2      68  Chicken Pulao
# 86     5.1      96        Biryani

# %%
df.head(10)
# Out:
#    height  weight favourite_Dish
# 0     5.8     101  Chicken Pulao
# 1     6.2      92        Biryani
# 2     5.9      62  Karahi Ghosht
# 3     5.9      95  Chicken Pulao
# 4     5.9      55  Chicken Pulao
# 5     5.3      59        Biryani
# 6     5.6      50          Pasta
# 7     5.9      76        Biryani
# 8     5.1      78        Biryani
# 9     5.4      68        Biryani

# %%
df.shape
# Out:
# (87, 3)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 87 entries, 0 to 86
# Data columns (total 3 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   height          87 non-null     float64
#  1   weight          87 non-null     int64
#  2   favourite_Dish  87 non-null     object
# dtypes: float64(1), int64(1), object(1)
# memory usage: 2.2+ KB
